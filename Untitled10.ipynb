# %% [markdown]
# <a href="https://colab.research.google.com/github/sonakshi-chand/machine-learning_sonakshi/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/insurance.csv')

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
import os
os.listdir('/content/drive/MyDrive')
# Out:
# ['Colab Notebooks',
#  'Classroom',
#  'yyj-beui-rkz – 8 Sept 2024.pdf',
#  'Untitled folder',
#  'EVS',
#  'C Assignment',
#  'Screenshot 2025-09-04 163821.png',
#  'Sonakshi Chand Id (3).pdf',
#  'Sonakshi Chand Id (2).pdf',
#  'Sonakshi Chand Id (1).pdf',
#  'Sonakshi Chand Id.pdf',
#  'Sonakshi Chand oops file.gdoc',
#  'DBMS project.pdf',
#  'PPT DBMS pdf.pdf',
#  'Dbms certificates.pdf',
#  'Kathak.pt',
#  'Kathak-Trainer.v2i.yolov11.zip',
#  'data',
#  'Untitled0.ipynb',
#  'ReportCard1.pdf',
#  'ReportCard1_merged (1) (1).pdf',
#  'ReportCard1_merged (1).pdf',
#  'Certificates.pdf',
#  'SIH 1_Hackquest_merged (1).pdf',
#  'Way of life (1).pdf',
#  'Way of life.pdf',
#  'Ted x.pdf',
#  'De assignment.pdf',
#  'insurance.csv']
